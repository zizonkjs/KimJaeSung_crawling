# %%
import pandas as pd

# %%
file=pd.read_csv('saramin_jobs_combined.csv')
jobdf=pd.DataFrame(file)
jobdf
# Out:
#                              회사이름  \
# 0    (주)유엔에이엔지니어링관심기업 등록에스케이그룹대기업
# 1                  주식회사썬테크관심기업 등록
# 2                주식회사에이치에스관심기업 등록
# 3         엘브이아이에스코리아(주)관심기업 등록외국계
# 4         엘브이아이에스코리아(주)관심기업 등록외국계
# ..                            ...
# 352              (주)다울디엔에스관심기업 등록
# 353        (주)커리어넷관심기업 등록파견·도급·대행
# 354         위더스파트너스(주)관심기업 등록헤드헌팅
# 355                  (주)왓콘관심기업 등록
# 356                  (주)왓콘관심기업 등록
#
#                                                채용정보  \
# 0                                 신입 및 경력직원 채용공고스크랩
# 1                           3조2교대 생산직(기숙사1인실,가불)스크랩
# 2                생산직 3조 2교대 사원 모집 (1인실기숙사/가불 가능)스크랩
# 3                 (AI/헬스케어) 시니어 소프트웨어 QA 엔지니어 모집스크랩
# 4                  (AI/Healthcare) 멀티미디어 디자이너 모집스크랩
# ..                                              ...
# 352  (주)다울디엔에스  상시채용 -AI/Big Data Solution 개발 부문스크랩
# 353                2024년 한국지능정보사회진흥원 3차 계약직 채용공고스크랩
# 354             디지털 농업 플랫폼 기업[SAP FCM, 3년이상, 대구]스크랩
# ...
